# %%
import pandas as pd
from sqlalchemy import create_engine

# Ustawienia połączenia z bazą danych
db_config = {
    'uri': "postgresql+psycopg2://postgres:ftZDAzKbfSK9WXh@localhost:5432/bimbasiqul"  # Twój ciąg połączenia
}

# Tworzenie połączenia
engine = create_engine(db_config['uri'])

# Sprawdzanie połączenia
try:
    with engine.connect() as conn:
        print("Połączenie z bazą danych zostało nawiązane pomyślnie!")
except Exception as e:
    print(f"Błąd podczas łączenia z bazą danych: {e}")
# Out:
# Połączenie z bazą danych zostało nawiązane pomyślnie!

# %%
# Zapytanie SQL
query = "SELECT * FROM daily_report;"  # Dopasuj do swojej tabeli
try:
    full_view = pd.read_sql(query, engine)
except Exception as e:
    print(f"Błąd podczas pobierania danych: {e}")

# %%
full_view
# Out:
#         entity_id      trip_id route_id route_short_name  stop_sequence  \
# 0            9110  1_4950175^+      901              901              0
# 1            9110  1_4950175^+      901              901              0
# 2            9110  1_4950175^+      901              901              0
# 3            9110  1_4950175^+      901              901              0
# 4            9110  1_4950175^+      901              901              1
# ...           ...          ...      ...              ...            ...
# 1986655      1774  5_8049186^+      189              189              0
# 1986656      1774  5_8049186^+      189              189              0
# 1986657      1774  5_8049186^+      189              189              0
# 1986658      1774  5_8049186^+      189              189              0
# 1986659      1774  5_8049186^+      189              189              0
#
#          arrival_delay     local_timestamp   latitude  longitude stop_id  ...  \
# ...

# %%
full_view.sample(10)
# Out:
#         entity_id       trip_id route_id route_short_name  stop_sequence  \
# 1164656      1621   5_8043622^+      166              166             14
# 804379        553  5_8008268^N+       18               18              0
# 845847        507  5_8008570^N+       24               24             17
# 348632       8030  5_7917769^S+      825              825             13
# 518245        419  5_8006325^N+       11               11             10
# 1001528       443  5_8009502^N+        7                7             16
# 509125        918  5_8006280^N+       10               10             14
# 1871333      1769   5_8048211^+      189              189              5
# 436306       7037  5_7919550^S+      729              729             14
# 860276        934  5_8008653^N+        3                3             29
#
#          arrival_delay     local_timestamp   latitude  longitude stop_id  ...  \
# 1164656            185 2024-12-09 14:38:24  52.380981  17.002529    3862  ...
# ...

# %%
# Zakładamy, że masz DataFrame df i linię, którą chcesz wybrać (np. route_id == '901')
selected_line = '193'

# Filtrowanie danych dla wybranej linii
df_selected_line = full_view[full_view['route_id'] == selected_line]

# %%
df_selected_line.sample(10)
# Out:
#         entity_id      trip_id route_id route_short_name  stop_sequence  \
# 1834831      1908  5_8047973^+      193              193             11
# 1840329      1020  5_8047997^+      193              193             29
# 1289875      1201  5_8044577^+      193              193             16
# 1847621      1011  5_8048047^+      193              193             31
# 1827512      1027  5_8047946^+      193              193             30
# 1294838      1904  5_8044607^+      193              193             19
# 1861119      1202  5_8048127^+      193              193              0
# 1297174      1904  5_8044615^+      193              193             13
# 1826212      1027  5_8047942^+      193              193              5
# 1836290      1908  5_8047978^+      193              193             11
#
#          arrival_delay     local_timestamp   latitude  longitude stop_id  ...  \
# 1834831            226 2024-12-09 08:57:57  52.401772  16.865089     773  ...
# ...
